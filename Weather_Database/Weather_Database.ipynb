# %%
# Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City":city.title(),
                         "Country":city_country,
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Current Description":city_description})
# If an error is experienced, skip the city.    
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | menongue
# Processing Record 4 of Set 1 | maragogi
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | kropotkin
# Processing Record 9 of Set 1 | kununurra
# Processing Record 10 of Set 1 | novikovo
# Processing Record 11 of Set 1 | thinadhoo
# Processing Record 12 of Set 1 | sovetskaya gavan
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | zdvinsk
# Processing Record 16 of Set 1 | saint-leu
# Processing Record 17 of Set 1 | xiongshi
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | ixtapa
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | mount gambier
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 1 | morros
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | rocha
# Processing Record 32 of Set 1 | celestun
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | hervey bay
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | krasnoselkup
# Processing Record 42 of Set 1 | banda aceh
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | payson
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | bathsheba
# Processing Record 2 of Set 2 | andenes
# Processing Record 3 of Set 2 | sao filipe
# Processing Record 4 of Set 2 | labuhan
# Processing Record 5 of Set 2 | araouane
# Processing Record 6 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | iskateley
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | matara
# Processing Record 15 of Set 2 | rayong
# Processing Record 16 of Set 2 | alice town
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | nouadhibou
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | punta arenas
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | pontypool
# Processing Record 29 of Set 2 | olafsvik
# Processing Record 30 of Set 2 | aklavik
# Processing Record 31 of Set 2 | ampanihy
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | ulladulla
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | cauquenes
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | nioro
# Processing Record 39 of Set 2 | nizhniye sergi
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | tarakan
# Processing Record 43 of Set 2 | nago
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | kudahuvadhoo
# Processing Record 47 of Set 2 | suluq
# Processing Record 48 of Set 2 | buin
# Processing Record 49 of Set 2 | castrillon
# Processing Record 50 of Set 2 | jinxiang
# Processing Record 1 of Set 3 | kidal
# Processing Record 2 of Set 3 | golden
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | bathurst
# Processing Record 7 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 3 | mwinilunga
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | cajamarca
# Processing Record 11 of Set 3 | yantai
# Processing Record 12 of Set 3 | alto araguaia
# Processing Record 13 of Set 3 | hambantota
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | alexandria
# Processing Record 16 of Set 3 | fort nelson
# Processing Record 17 of Set 3 | batemans bay
# Processing Record 18 of Set 3 | arman
# Processing Record 19 of Set 3 | mulanje
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | zaozerne
# Processing Record 23 of Set 3 | tessalit
# Processing Record 24 of Set 3 | moulins
# Processing Record 25 of Set 3 | culaman
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | vila velha
# Processing Record 28 of Set 3 | dzerzhinsk
# Processing Record 29 of Set 3 | beringovskiy
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | tugalan
# City not found. Skipping...
# Processing Record 32 of Set 3 | caravelas
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | rio tercero
# Processing Record 35 of Set 3 | qasigiannguit
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 3 | maymyo
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | tekirdag
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 3 | bowen
# Processing Record 45 of Set 3 | tabuk
# Processing Record 46 of Set 3 | moree
# Processing Record 47 of Set 3 | atuona
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | necochea
# Processing Record 50 of Set 3 | pitanga
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | lagoa
# Processing Record 3 of Set 4 | aswan
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | chak azam sahu
# Processing Record 6 of Set 4 | bitung
# Processing Record 7 of Set 4 | cayenne
# City not found. Skipping...
# Processing Record 8 of Set 4 | tura
# City not found. Skipping...
# Processing Record 9 of Set 4 | talnakh
# City not found. Skipping...
# Processing Record 10 of Set 4 | barpathar
# City not found. Skipping...
# Processing Record 11 of Set 4 | narsaq
# City not found. Skipping...
# Processing Record 12 of Set 4 | the valley
# Processing Record 13 of Set 4 | vila franca do campo
# Processing Record 14 of Set 4 | calama
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | sakaiminato
# Processing Record 18 of Set 4 | luwuk
# Processing Record 19 of Set 4 | paso de carrasco
# Processing Record 20 of Set 4 | la ronge
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | iranduba
# Processing Record 24 of Set 4 | safford
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | norsup
# Processing Record 27 of Set 4 | oussouye
# Processing Record 28 of Set 4 | yatou
# Processing Record 29 of Set 4 | bodden town
# Processing Record 30 of Set 4 | fairbanks
# Processing Record 31 of Set 4 | gushikawa
# Processing Record 32 of Set 4 | lensk
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | matagami
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | roald
# Processing Record 37 of Set 4 | gigmoto
# Processing Record 38 of Set 4 | ribeira grande
# Processing Record 39 of Set 4 | saint-augustin
# Processing Record 40 of Set 4 | bugene
# Processing Record 41 of Set 4 | careiro da varzea
# Processing Record 42 of Set 4 | buchanan
# Processing Record 43 of Set 4 | barranca
# Processing Record 44 of Set 4 | quatre cocos
# Processing Record 45 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 4 | uzhhorod
# Processing Record 47 of Set 4 | tsentralnyy
# City not found. Skipping...
# Processing Record 48 of Set 4 | dumas
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | jinchang
# Processing Record 1 of Set 5 | linqiong
# Processing Record 2 of Set 5 | opuwo
# Processing Record 3 of Set 5 | kaka
# Processing Record 4 of Set 5 | camara de lobos
# Processing Record 5 of Set 5 | katherine
# Processing Record 6 of Set 5 | port hardy
# Processing Record 7 of Set 5 | puerto ayora
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | george town
# Processing Record 10 of Set 5 | pinsk
# Processing Record 11 of Set 5 | nishihara
# Processing Record 12 of Set 5 | rawson
# Processing Record 13 of Set 5 | fairfield
# Processing Record 14 of Set 5 | kenai
# Processing Record 15 of Set 5 | saint-joseph
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | champerico
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | salto
# Processing Record 20 of Set 5 | santiago
# Processing Record 21 of Set 5 | natal
# Processing Record 22 of Set 5 | kaoma
# Processing Record 23 of Set 5 | tiznit
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | caramay
# Processing Record 26 of Set 5 | buraydah
# Processing Record 27 of Set 5 | husavik
# Processing Record 28 of Set 5 | honiara
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | linfen
# Processing Record 31 of Set 5 | weyburn
# Processing Record 32 of Set 5 | alofi
# Processing Record 33 of Set 5 | gueugnon
# Processing Record 34 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 35 of Set 5 | hay river
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | mosquera
# Processing Record 38 of Set 5 | puerto escondido
# Processing Record 39 of Set 5 | chuy
# Processing Record 40 of Set 5 | nurlat
# Processing Record 41 of Set 5 | kilindoni
# Processing Record 42 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 5 | magadan
# Processing Record 44 of Set 5 | copiapo
# Processing Record 45 of Set 5 | sayyan
# Processing Record 46 of Set 5 | dubrovnik
# Processing Record 47 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | severo-kurilsk
# Processing Record 49 of Set 5 | samarai
# Processing Record 50 of Set 5 | camacupa
# Processing Record 1 of Set 6 | bilibino
# Processing Record 2 of Set 6 | wa
# City not found. Skipping...
# Processing Record 3 of Set 6 | mecca
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | tyukhtet
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | yelizovo
# Processing Record 9 of Set 6 | shirvan
# Processing Record 10 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 6 | dubovyy umet
# Processing Record 12 of Set 6 | msowero
# Processing Record 13 of Set 6 | jacareacanga
# Processing Record 14 of Set 6 | ambulu
# Processing Record 15 of Set 6 | maceio
# Processing Record 16 of Set 6 | kuala terengganu
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | bubaque
# Processing Record 19 of Set 6 | lazaro cardenas
# Processing Record 20 of Set 6 | new norfolk
# Processing Record 21 of Set 6 | oranjestad
# Processing Record 22 of Set 6 | college
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 6 | farafangana
# Processing Record 28 of Set 6 | gogrial
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | ambovombe
# Processing Record 31 of Set 6 | tel aviv-yafo
# Processing Record 32 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 6 | offa
# Processing Record 34 of Set 6 | alekseyevsk
# Processing Record 35 of Set 6 | port macquarie
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | nuuk
# Processing Record 38 of Set 6 | guanare
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | kodiak
# Processing Record 41 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 6 | endicott
# Processing Record 43 of Set 6 | minsk
# Processing Record 44 of Set 6 | salinopolis
# Processing Record 45 of Set 6 | pocone
# Processing Record 46 of Set 6 | kinshasa
# Processing Record 47 of Set 6 | roma
# Processing Record 48 of Set 6 | astana
# Processing Record 49 of Set 6 | sola
# Processing Record 50 of Set 6 | pointe michel
# Processing Record 1 of Set 7 | mahenge
# Processing Record 2 of Set 7 | kondopoga
# Processing Record 3 of Set 7 | qaqortoq
# Processing Record 4 of Set 7 | agadir
# Processing Record 5 of Set 7 | korla
# Processing Record 6 of Set 7 | iqaluit
# Processing Record 7 of Set 7 | kaili
# Processing Record 8 of Set 7 | zhanaozen
# Processing Record 9 of Set 7 | kaitangata
# Processing Record 10 of Set 7 | bambanglipuro
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | bisert
# Processing Record 13 of Set 7 | rudnyy
# Processing Record 14 of Set 7 | port elizabeth
# Processing Record 15 of Set 7 | mercedes
# Processing Record 16 of Set 7 | mavelikara
# Processing Record 17 of Set 7 | maple creek
# Processing Record 18 of Set 7 | huarmey
# Processing Record 19 of Set 7 | colares
# Processing Record 20 of Set 7 | ca mau
# Processing Record 21 of Set 7 | leh
# Processing Record 22 of Set 7 | atar
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | vestmannaeyjar
# Processing Record 25 of Set 7 | sovetskiy
# Processing Record 26 of Set 7 | dakar
# Processing Record 27 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 7 | byron bay
# Processing Record 29 of Set 7 | khasan
# Processing Record 30 of Set 7 | okhotsk
# Processing Record 31 of Set 7 | kavaratti
# Processing Record 32 of Set 7 | shchuchye
# City not found. Skipping...
# Processing Record 33 of Set 7 | waingapu
# Processing Record 34 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 7 | meulaboh
# Processing Record 37 of Set 7 | etchoropo
# Processing Record 38 of Set 7 | deniliquin
# Processing Record 39 of Set 7 | denizli
# Processing Record 40 of Set 7 | mogok
# Processing Record 41 of Set 7 | manzanillo
# Processing Record 42 of Set 7 | paramonga
# Processing Record 43 of Set 7 | pemba
# Processing Record 44 of Set 7 | port augusta
# Processing Record 45 of Set 7 | kaitong
# Processing Record 46 of Set 7 | sorong
# Processing Record 47 of Set 7 | pucallpa
# Processing Record 48 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | luderitz
# Processing Record 1 of Set 8 | kashary
# Processing Record 2 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 8 | narasannapeta
# Processing Record 5 of Set 8 | virginia beach
# Processing Record 6 of Set 8 | verkhnevilyuysk
# Processing Record 7 of Set 8 | lang suan
# Processing Record 8 of Set 8 | sakakah
# Processing Record 9 of Set 8 | solsona
# Processing Record 10 of Set 8 | nouakchott
# Processing Record 11 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 8 | tanout
# Processing Record 13 of Set 8 | rundu
# Processing Record 14 of Set 8 | torbay
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | nanortalik
# Processing Record 17 of Set 8 | mayumba
# Processing Record 18 of Set 8 | muncie
# Processing Record 19 of Set 8 | jasper
# Processing Record 20 of Set 8 | tiarei
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | olenegorsk
# Processing Record 23 of Set 8 | roebourne
# Processing Record 24 of Set 8 | dicabisagan
# Processing Record 25 of Set 8 | warrington
# Processing Record 26 of Set 8 | birin
# Processing Record 27 of Set 8 | tanete
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 8 | mgandu
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | tarko-sale
# Processing Record 33 of Set 8 | kerrville
# Processing Record 34 of Set 8 | egvekinot
# Processing Record 35 of Set 8 | iralaya
# Processing Record 36 of Set 8 | sinnamary
# Processing Record 37 of Set 8 | pangnirtung
# Processing Record 38 of Set 8 | catamarca
# Processing Record 39 of Set 8 | manakara
# Processing Record 40 of Set 8 | santa fe
# Processing Record 41 of Set 8 | ilinskiy
# Processing Record 42 of Set 8 | airai
# Processing Record 43 of Set 8 | riyadh
# Processing Record 44 of Set 8 | conceicao do araguaia
# Processing Record 45 of Set 8 | los llanos de aridane
# Processing Record 46 of Set 8 | monrovia
# Processing Record 47 of Set 8 | disna
# Processing Record 48 of Set 8 | hualmay
# Processing Record 49 of Set 8 | leshukonskoye
# Processing Record 50 of Set 8 | trussville
# Processing Record 1 of Set 9 | oblesevo
# Processing Record 2 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 3 of Set 9 | kysyl-syr
# Processing Record 4 of Set 9 | polistena
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | maraa
# Processing Record 7 of Set 9 | ponta do sol
# Processing Record 8 of Set 9 | yukon
# Processing Record 9 of Set 9 | christchurch
# Processing Record 10 of Set 9 | uarini
# Processing Record 11 of Set 9 | seoul
# Processing Record 12 of Set 9 | deputatskiy
# Processing Record 13 of Set 9 | mandalgovi
# Processing Record 14 of Set 9 | norman wells
# Processing Record 15 of Set 9 | zalantun
# Processing Record 16 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 9 | jatai
# Processing Record 18 of Set 9 | urengoy
# Processing Record 19 of Set 9 | half moon bay
# Processing Record 20 of Set 9 | paragominas
# Processing Record 21 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 9 | tilichiki
# Processing Record 23 of Set 9 | cabo san lucas
# Processing Record 24 of Set 9 | ankara
# Processing Record 25 of Set 9 | porto santo
# Processing Record 26 of Set 9 | tiksi
# Processing Record 27 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 28 of Set 9 | itarema
# Processing Record 29 of Set 9 | mahanoro
# Processing Record 30 of Set 9 | banjar
# Processing Record 31 of Set 9 | belaya gora
# Processing Record 32 of Set 9 | kirakira
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | esperantina
# Processing Record 35 of Set 9 | kvitok
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | henties bay
# Processing Record 38 of Set 9 | mayaky
# Processing Record 39 of Set 9 | ostrovnoy
# Processing Record 40 of Set 9 | mayo
# Processing Record 41 of Set 9 | beloha
# Processing Record 42 of Set 9 | marsa matruh
# Processing Record 43 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 9 | kawalu
# Processing Record 45 of Set 9 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 46 of Set 9 | sao felix do xingu
# Processing Record 47 of Set 9 | svetlyy yar
# Processing Record 48 of Set 9 | bethel
# Processing Record 49 of Set 9 | ojinaga
# Processing Record 50 of Set 9 | santa cruz
# Processing Record 1 of Set 10 | lancaster
# Processing Record 2 of Set 10 | amuntai
# Processing Record 3 of Set 10 | palmer
# Processing Record 4 of Set 10 | baykit
# Processing Record 5 of Set 10 | puerto leguizamo
# Processing Record 6 of Set 10 | kathu
# Processing Record 7 of Set 10 | porto novo
# Processing Record 8 of Set 10 | litovko
# Processing Record 9 of Set 10 | maragogipe
# Processing Record 10 of Set 10 | shingu
# Processing Record 11 of Set 10 | sobolevo
# Processing Record 12 of Set 10 | nizhnyaya salda
# Processing Record 13 of Set 10 | krasnoarmeysk
# Processing Record 14 of Set 10 | nhulunbuy
# Processing Record 15 of Set 10 | salaspils
# Processing Record 16 of Set 10 | shimoda
# Processing Record 17 of Set 10 | high level
# Processing Record 18 of Set 10 | auki
# Processing Record 19 of Set 10 | usinsk
# Processing Record 20 of Set 10 | pafos
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 10 | accra
# Processing Record 24 of Set 10 | yar-sale
# Processing Record 25 of Set 10 | biloela
# Processing Record 26 of Set 10 | wilmington
# Processing Record 27 of Set 10 | szigetvar
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | xiaoyi
# Processing Record 30 of Set 10 | vila do maio
# Processing Record 31 of Set 10 | bacolod
# Processing Record 32 of Set 10 | rio grande city
# Processing Record 33 of Set 10 | arawa
# Processing Record 34 of Set 10 | abalak
# Processing Record 35 of Set 10 | pisco
# Processing Record 36 of Set 10 | goodlettsville
# Processing Record 37 of Set 10 | jumla
# Processing Record 38 of Set 10 | ahipara
# Processing Record 39 of Set 10 | truro
# Processing Record 40 of Set 10 | cap malheureux
# Processing Record 41 of Set 10 | teknaf
# Processing Record 42 of Set 10 | shar
# Processing Record 43 of Set 10 | valparaiso
# Processing Record 44 of Set 10 | bakchar
# Processing Record 45 of Set 10 | kuminskiy
# Processing Record 46 of Set 10 | gamboma
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | graciano sanchez
# Processing Record 49 of Set 10 | oktyabrskoye
# Processing Record 50 of Set 10 | akhnur
# Processing Record 1 of Set 11 | kon tum
# Processing Record 2 of Set 11 | klaksvik
# Processing Record 3 of Set 11 | bafq
# Processing Record 4 of Set 11 | ust-nera
# Processing Record 5 of Set 11 | beian
# Processing Record 6 of Set 11 | teguldet
# Processing Record 7 of Set 11 | allanridge
# Processing Record 8 of Set 11 | paradise
# Processing Record 9 of Set 11 | hollola
# Processing Record 10 of Set 11 | lufilufi
# Processing Record 11 of Set 11 | kasama
# Processing Record 12 of Set 11 | pauini
# Processing Record 13 of Set 11 | pontianak
# Processing Record 14 of Set 11 | batticaloa
# Processing Record 15 of Set 11 | gat
# Processing Record 16 of Set 11 | qandala
# Processing Record 17 of Set 11 | taltal
# Processing Record 18 of Set 11 | namatanai
# Processing Record 19 of Set 11 | batagay-alyta
# Processing Record 20 of Set 11 | san felipe
# Processing Record 21 of Set 11 | odugathur
# City not found. Skipping...
# Processing Record 22 of Set 11 | chickasha
# Processing Record 23 of Set 11 | cabitan
# Processing Record 24 of Set 11 | ankpa
# Processing Record 25 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 11 | providencia
# Processing Record 27 of Set 11 | coquimbo
# Processing Record 28 of Set 11 | lundazi
# Processing Record 29 of Set 11 | vavoua
# Processing Record 30 of Set 11 | merauke
# Processing Record 31 of Set 11 | trinidad
# Processing Record 32 of Set 11 | punalur
# Processing Record 33 of Set 11 | north battleford
# Processing Record 34 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 11 | freeport
# Processing Record 36 of Set 11 | rio grande
# Processing Record 37 of Set 11 | vardo
# Processing Record 38 of Set 11 | grindavik
# Processing Record 39 of Set 11 | tromso
# Processing Record 40 of Set 11 | morant bay
# Processing Record 41 of Set 11 | bonavista
# Processing Record 42 of Set 11 | dengfeng
# Processing Record 43 of Set 11 | ponta pora
# Processing Record 44 of Set 11 | hokitika
# Processing Record 45 of Set 11 | inirida
# Processing Record 46 of Set 11 | sabha
# Processing Record 47 of Set 11 | grand gaube
# Processing Record 48 of Set 11 | iquique
# Processing Record 49 of Set 11 | port hedland
# Processing Record 50 of Set 11 | brae
# Processing Record 1 of Set 12 | rioja
# Processing Record 2 of Set 12 | tabalosos
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | champasak
# Processing Record 5 of Set 12 | mana
# Processing Record 6 of Set 12 | san policarpo
# Processing Record 7 of Set 12 | buta
# Processing Record 8 of Set 12 | nurota
# Processing Record 9 of Set 12 | lac du bonnet
# Processing Record 10 of Set 12 | panara
# Processing Record 11 of Set 12 | jaranwala
# Processing Record 12 of Set 12 | troitsko-pechorsk
# Processing Record 13 of Set 12 | coxim
# Processing Record 14 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 15 of Set 12 | ginir
# Processing Record 16 of Set 12 | areosa
# Processing Record 17 of Set 12 | biak
# Processing Record 18 of Set 12 | itacoatiara
# Processing Record 19 of Set 12 | iberia
# Processing Record 20 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | herat
# Processing Record 23 of Set 12 | orange cove
# Processing Record 24 of Set 12 | preobrazheniye
# Processing Record 25 of Set 12 | komsomolskiy
# Processing Record 26 of Set 12 | santiago del estero
# Processing Record 27 of Set 12 | anloga
# Processing Record 28 of Set 12 | comodoro rivadavia
# Processing Record 29 of Set 12 | tra vinh
# Processing Record 30 of Set 12 | tsiroanomandidy
# Processing Record 31 of Set 12 | omboue
# Processing Record 32 of Set 12 | bagdarin
# Processing Record 33 of Set 12 | savonlinna
# Processing Record 34 of Set 12 | wadi musa
# Processing Record 35 of Set 12 | avera
# Processing Record 36 of Set 12 | bukama
# Processing Record 37 of Set 12 | ulagan
# Processing Record 38 of Set 12 | semme
# Processing Record 39 of Set 12 | bereda
# Processing Record 40 of Set 12 | kikwit
# Processing Record 41 of Set 12 | ambilobe
# Processing Record 42 of Set 12 | taraza
# Processing Record 43 of Set 12 | akom
# Processing Record 44 of Set 12 | axim
# Processing Record 45 of Set 12 | winnemucca
# Processing Record 46 of Set 12 | muros
# Processing Record 47 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 12 | mahdasht
# Processing Record 49 of Set 12 | touros
# Processing Record 50 of Set 12 | coahuayana
# Processing Record 1 of Set 13 | mitu
# Processing Record 2 of Set 13 | port keats
# Processing Record 3 of Set 13 | vanimo
# Processing Record 4 of Set 13 | kolondieba
# Processing Record 5 of Set 13 | abu dhabi
# Processing Record 6 of Set 13 | hazorasp
# Processing Record 7 of Set 13 | san patricio
# Processing Record 8 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 13 | chingola
# Processing Record 10 of Set 13 | sistranda
# Processing Record 11 of Set 13 | naze
# Processing Record 12 of Set 13 | poggibonsi
# Processing Record 13 of Set 13 | dabola
# Processing Record 14 of Set 13 | wolfsburg
# Processing Record 15 of Set 13 | ginda
# Processing Record 16 of Set 13 | verkhnyaya inta
# Processing Record 17 of Set 13 | karratha
# Processing Record 18 of Set 13 | wankaner
# Processing Record 19 of Set 13 | guthrie
# Processing Record 20 of Set 13 | laguna
# Processing Record 21 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 13 | omsukchan
# Processing Record 23 of Set 13 | tomigusuku
# Processing Record 24 of Set 13 | nanakuli
# Processing Record 25 of Set 13 | greenock
# Processing Record 26 of Set 13 | yermish
# Processing Record 27 of Set 13 | fereydunshahr
# Processing Record 28 of Set 13 | west lorne
# Processing Record 29 of Set 13 | talakan
# Processing Record 30 of Set 13 | sao miguel do araguaia
# Processing Record 31 of Set 13 | aguimes
# Processing Record 32 of Set 13 | san joaquin
# Processing Record 33 of Set 13 | ballina
# Processing Record 34 of Set 13 | dourbali
# Processing Record 35 of Set 13 | imeni poliny osipenko
# Processing Record 36 of Set 13 | chuzhou
# Processing Record 37 of Set 13 | uvalde
# Processing Record 38 of Set 13 | humberto de campos
# Processing Record 39 of Set 13 | forbesganj
# Processing Record 40 of Set 13 | coihaique
# Processing Record 41 of Set 13 | zabol
# Processing Record 42 of Set 13 | zinder
# Processing Record 43 of Set 13 | tanggu
# Processing Record 44 of Set 13 | khanpur
# Processing Record 45 of Set 13 | along
# Processing Record 46 of Set 13 | nargana
# Processing Record 47 of Set 13 | otacilio costa
# Processing Record 48 of Set 13 | broken hill
# Processing Record 49 of Set 13 | bayeux
# Processing Record 50 of Set 13 | victoria point
# Processing Record 1 of Set 14 | anchorage
# Processing Record 2 of Set 14 | ugoofaaru
# Processing Record 3 of Set 14 | luganville
# Processing Record 4 of Set 14 | kukes
# Processing Record 5 of Set 14 | neiafu
# Processing Record 6 of Set 14 | rizhao
# Processing Record 7 of Set 14 | maharajganj
# Processing Record 8 of Set 14 | sivaki
# Processing Record 9 of Set 14 | lagos
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | san andres
# Processing Record 12 of Set 14 | port blair
# Processing Record 13 of Set 14 | saint-cyr-sur-loire
# Processing Record 14 of Set 14 | ashland
# Processing Record 15 of Set 14 | constantine
# Processing Record 16 of Set 14 | graham
# Processing Record 17 of Set 14 | mitsamiouli
# Processing Record 18 of Set 14 | aksu
# Processing Record 19 of Set 14 | kisangani
# Processing Record 20 of Set 14 | geraldton
# Processing Record 21 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 14 | havelock
# Processing Record 23 of Set 14 | madisonville
# Processing Record 24 of Set 14 | chagoda
# Processing Record 25 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 14 | ayan
# Processing Record 27 of Set 14 | mabaruma
# Processing Record 28 of Set 14 | nisia floresta
# Processing Record 29 of Set 14 | mahibadhoo
# Processing Record 30 of Set 14 | nizhniy ingash
# Processing Record 31 of Set 14 | mehamn
# Processing Record 32 of Set 14 | balabac
# Processing Record 33 of Set 14 | dawson
# Processing Record 34 of Set 14 | karoi
# Processing Record 35 of Set 14 | pangody
# Processing Record 36 of Set 14 | aubenas
# Processing Record 37 of Set 14 | makat
# Processing Record 38 of Set 14 | guane
# Processing Record 39 of Set 14 | hatillo
# Processing Record 40 of Set 14 | te anau
# Processing Record 41 of Set 14 | salinas
# Processing Record 42 of Set 14 | nizhniy kuranakh
# Processing Record 43 of Set 14 | pecos
# Processing Record 44 of Set 14 | maldonado
# Processing Record 45 of Set 14 | mumford
# Processing Record 46 of Set 14 | diffa
# Processing Record 47 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 14 | barcelos
# Processing Record 49 of Set 14 | launceston
# Processing Record 50 of Set 14 | tadine
# Processing Record 1 of Set 15 | barras
# Processing Record 2 of Set 15 | nizhnyaya maktama
# Processing Record 3 of Set 15 | gravdal
# Processing Record 4 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 15 | mackay
# Processing Record 6 of Set 15 | castilho
# Processing Record 7 of Set 15 | wanning
# Processing Record 8 of Set 15 | goderich
# Processing Record 9 of Set 15 | sao jose da coroa grande
# Processing Record 10 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 11 of Set 15 | noumea
# Processing Record 12 of Set 15 | bolu
# Processing Record 13 of Set 15 | lima
# Processing Record 14 of Set 15 | boromlya
# Processing Record 15 of Set 15 | rajpipla
# Processing Record 16 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 15 | lyuban
# Processing Record 18 of Set 15 | kastamonu
# Processing Record 19 of Set 15 | mandali
# Processing Record 20 of Set 15 | umm kaddadah
# Processing Record 21 of Set 15 | broome
# Processing Record 22 of Set 15 | bandarbeyla
# Processing Record 23 of Set 15 | sampit
# Processing Record 24 of Set 15 | waipawa
# Processing Record 25 of Set 15 | maniitsoq
# Processing Record 26 of Set 15 | beeville
# Processing Record 27 of Set 15 | haines junction
# Processing Record 28 of Set 15 | pinawa
# Processing Record 29 of Set 15 | taoudenni
# Processing Record 30 of Set 15 | weihai
# Processing Record 31 of Set 15 | guekedou
# City not found. Skipping...
# Processing Record 32 of Set 15 | lienz
# Processing Record 33 of Set 15 | gunjur
# Processing Record 34 of Set 15 | mareeba
# Processing Record 35 of Set 15 | bonthe
# Processing Record 36 of Set 15 | isangel
# Processing Record 37 of Set 15 | khorixas
# Processing Record 38 of Set 15 | porbandar
# Processing Record 39 of Set 15 | corowa
# Processing Record 40 of Set 15 | rafaela
# Processing Record 41 of Set 15 | mizdah
# Processing Record 42 of Set 15 | gamba
# Processing Record 43 of Set 15 | panama city
# Processing Record 44 of Set 15 | saint-francois
# Processing Record 45 of Set 15 | newport
# Processing Record 46 of Set 15 | camocim
# Processing Record 47 of Set 15 | marawi
# Processing Record 48 of Set 15 | skjervoy
# Processing Record 49 of Set 15 | damilag
# Processing Record 50 of Set 15 | pokhara
# Processing Record 1 of Set 16 | beyneu
# Processing Record 2 of Set 16 | majene
# Processing Record 3 of Set 16 | independencia
# Processing Record 4 of Set 16 | kolyvan
# Processing Record 5 of Set 16 | picton
# Processing Record 6 of Set 16 | mbandaka
# Processing Record 7 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 16 | suicheng
# Processing Record 9 of Set 16 | kargil
# Processing Record 10 of Set 16 | bichena
# Processing Record 11 of Set 16 | yevlax
# Processing Record 12 of Set 16 | rio gallegos
# Processing Record 13 of Set 16 | abong mbang
# Processing Record 14 of Set 16 | shieli
# Processing Record 15 of Set 16 | narrabri
# Processing Record 16 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 16 | praia da vitoria
# Processing Record 18 of Set 16 | montepuez
# Processing Record 19 of Set 16 | aykhal
# Processing Record 20 of Set 16 | narino
# Processing Record 21 of Set 16 | gurinhem
# Processing Record 22 of Set 16 | hami
# Processing Record 23 of Set 16 | lakes entrance
# Processing Record 24 of Set 16 | selenginsk
# Processing Record 25 of Set 16 | nabire
# Processing Record 26 of Set 16 | kontagora
# Processing Record 27 of Set 16 | dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_city_df = pd.DataFrame(city_data)
weather_city_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany      US  42.6001  -73.9662     66.63        46           0
# 1  Mar Del Plata      AR -38.0023  -57.5575     65.88        60         100
# 2       Menongue      AO -14.6585   17.6910     64.09        87         100
# 3       Maragogi      BR  -9.0122  -35.2225     81.72        73          69
# 4           Hilo      US  19.7297 -155.0900     80.28        89         100
# 5       Katsuura      JP  35.1333  140.3000     62.19        95           6
# 6         Faanui      PF -16.4833 -151.7500     82.15        72           8
# 7      Kropotkin      RU  45.4375   40.5756     42.98        81         100
# 8      Kununurra      AU -15.7667  128.7333     73.38       100         100
# 9       Novikovo      RU  51.1537   37.8879     54.95        85         100
#
#    Wind Speed Current Description
# 0       12.28           clear sky
# 1       11.99          light rain
# 2        0.96     overcast clouds
# 3        7.36       broken clouds
# 4        8.01          light rain
# 5       13.00           clear sky
# 6       15.66           clear sky
# 7       24.58     overcast clouds
# 8        4.61          light rain
# 9        5.61     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_city_df.to_csv(output_data_file,index=False)
